# %%
import numpy
from utils import display_np_arrays_as_images

display_np_arrays_as_images()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy
# ----> 2 from utils import display_np_arrays_as_images
#       4 display_np_arrays_as_images()
#
# ImportError: cannot import name 'display_np_arrays_as_images' from 'utils' (c:\Users\OneRaise\miniconda3\envs\myenv\Lib\site-packages\utils\__init__.py)

# %%
imp
